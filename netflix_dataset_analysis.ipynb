# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
netflix=pd.read_csv("/kaggle/input/netflix-shows/netflix_titles.csv")
netflix1=pd.read_csv("/kaggle/input/netflix-shows/netflix_titles.csv")
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/netflix-shows/netflix_titles.csv

# %%
netflix.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
#to access the second row of the netflix shows dataset
#both iloc and loc are row first and column second
netflix.iloc[1]
#in case we want to access all the titles then
netflix.iloc[:,2]
#we can also go for label based selections,here we are trying to get the lsit of all countries where the netflix shows are produces
netflix.loc[:,"country"]
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %%
# * Manipulating the index *
#release year will be put in the beginning
netflix.set_index("release_year")
#If we want to check a certain show is available on netflix
netflix.loc[netflix.title.isin(["Kota Factory"])]
#If we want to check if any data is empty in our dataset(gives boolean output)
netflix.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# * Assigning a data *
#Here we are adding a new column called certified and giving it a default value not certified which we will change according to our conditions 
netflix["certified"]=" not certified"
netflix["rating"]=netflix1["rating"]
netflix.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
#Summary Functions and Maps
#For example we want to know the number of shows of a certain rating type
netflix.rating.value_counts()
#This function is to get the names of the different types of ratings that are available
netflix.rating.unique()
#MAPS
#If we want to change the status of all shows from not certified to certified
def remark_ratings(row):
    row.certified="certified"
    return row
netflix.apply(remark_ratings,axis="columns")
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Now if we want to find the oldest show available in this Netflix data
oldest_show=netflix.release_year.idxmin()
oldest_show_is=netflix.loc[oldest_show,"title"]
print("The oldest show is ",oldest_show_is)#Here we have managed to find the oldest show in the given netflix data Pioneers: First Women Filmmakers
# Out:
# The oldest show is  Pioneers: First Women Filmmakers*

# %%
#If we want to find a particular genre or type of show
#Let us consider we want to know the number of documentaries available
n_doc=netflix.listed_in.map(lambda desc:"Documentaries" in desc).sum()
documentary_counts=pd.Series([n_doc],index=["Documentaries"])
print(documentary_counts)
# Out:
# Documentaries    869
# dtype: int64

# %%
#Now if we want a list of number of  movies and shows by a certain director
netflix.groupby("director").size()
# Out:
# director
# A. L. Vijay            2
# A. Raajdheep           1
# A. Salaam              1
# A.R. Murugadoss        2
# Aadish Keluskar        1
#                       ..
# Çagan Irmak            1
# Ísold Uggadóttir       1
# Óskar Thór Axelsson    1
# Ömer Faruk Sorak       2
# Şenol Sönmez           2
# Length: 4528, dtype: int64

# %%
#Datatypes and Missing Values
#to get the data type of a particular column
netflix.release_year.dtype
#Now all the empty values in our list have been tagged as NaN
#If I want to change all the NaN in the director column to anonymous
netflix["director"]=netflix["director"].fillna("Anonymous")
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water        Anonymous
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans        Anonymous
# 4      s5  TV Show           Kota Factory        Anonymous
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...
